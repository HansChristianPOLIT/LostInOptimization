# %% [markdown]
# # Durable Consumption Model

# %% [markdown]
# This notebooks shows you how to use the tools of the **consav** package to solve a **durable consumption model** with either
#
# 1. **vfi**: standard value function iteration (written in C++)
# 2. **nvfi**: nested value function iteration (writen in Python, or **nvfi_cpp** is written i C++)
# 3. **negm**: nested endogenous grid point method (writen in Python, or **negm_cpp** is written i C++)
#
# The implemented solution methods are explained in detail in [A Guide to Solve Non-Convex Consumption-Saving Models](https://doi.org/10.1007/s10614-020-10045-x).

# %% [markdown]
# **Computer used for timings:** Windows 10 computer with 2x Intel(R) Xeon(R) Gold 6254 3.10 GHz CPUs (18 cores, 36 logical processes each) and 768 GB of RAM.

# %% [markdown]
# ## Model equations

# %% [markdown]
# The **states** are:
#
# 1. the persistent component of income, $p_t$
# 2. stock of the durable good, $n_t$
# 3. cash-on-hand, $m_t$
#
# The **choices** are:
#
# 1. durable consumption, $d_t$
# 2. non-durable consumption, $c_t$
#
# **Utility** is CRRA over a Cobb-Douglas aggregate:
#
# $$ u(c_{t},d_{t})=\frac{(c_{t}^{\alpha}(d_{t}+\underline{d})^{1-\alpha})^{1-\rho}}{1-\rho} $$
#
# **Income** follows a persistent-transitory process:
#
# $$
# \begin{aligned}
# p_{t+1}&=\psi_{t+1}p_{t}^{\lambda},\,\,\,\log\psi_{t+1}\sim\mathcal{N}(-0.5\sigma_{\psi}^{2},\sigma_{\psi}^{2}) \\ y_{t+1}&=\xi_{t+1}p_{t+1},\,\,\,\log\xi_{t+1}\sim\mathcal{N}(-0.5\sigma_{\xi}^{2},\sigma_{\xi}^{2})
# \end{aligned}
# $$
#
# The household **cannot borrow** and the **interest rate** on savings is $r$. Adjusting the stock of durables is subject to a **proportional adjustment cost** $\tau$ and **durables depreciates** with a rate of $\delta$.
#
# $$ n_{t+1}=(1-\delta)d_{t} $$
#
# The **bellman equation** is
#
# $$
# \begin{aligned}
# v_{t}(p_{t},n_{t},m_{t})&=\max\{v_{t}^{keep}(p_{t},n_{t},m_{t}),v_{t}^{adj.}(p_{t},x_{t})\}\\&\text{s.t.}&\\x_{t}&=&m_{t}+(1-\tau)n_{t}
# \end{aligned}
# $$
#
#  where
#
# $$
# \begin{aligned}
# v_{t}^{keep}(p_{t},n_{t},m_{t})&=\max_{c_{t}}u(c_{t},n_{t})+\beta\mathbb{E}_{t}[v_{t+1}(p_{t+1},n_{t+1},m_{t+1})]\\&\text{s.t.}&\\
# a_{t}&= m_{t}-c_{t}\\
# m_{t+1}&= (1+r)a_{t}+y_{t+1}\\
# n_{t+1}&= (1-\delta)n_{t}\\
# a_{t}&\geq 0
# \end{aligned}
# $$
#
# and
#
# $$
# \begin{aligned}
# v_{t}^{adj.}(p_{t},x_{t})&= \max_{c_{t},d_{t}}u(c_{t},d_{t})+\beta\mathbb{E}_{t}[v_{t+1}(p_{t+1},n_{t+1},m_{t+1})]\\&\text{s.t.}&\\
# a_{t}&= x_{t}-c_{t}-d_{t}\\
# m_{t+1}&= (1+r)a_{t}+y_{t+1}\\
# n_{t+1}&= (1-\delta)n_{t}\\
# a_{t}&\geq 0
# \end{aligned}
# $$

# %% [markdown]
# ## Overview

# %% [markdown]
# The model solved in this notebook is written in **DurableConsumptionModelModel.py**.
#
# It provides a class called **DurableConsumptionModelClass** inheriting its basic interface from the **ModelClass**.

# %% [markdown]
# A short **overview** of the interface is:
#
# 1. The class must have a **name** and must contain **three central methods**:
#
#     1. `settings()` Choose fundamental settings (called *first* when initializing).
#
#         1. `namespaces (list of str)`: In addition to `.par`, `.sol`, `.sim`, each element will be available as an attribute (can be used in numba jitted functions).
#         2. `other_attrs (list of str)`: Other attributes to be saved (can *not* be used in numba jitted functions).
#         3. `savefolder (str)`: Folder to save the model in.
#         4. `not_float list of str)`: List of non-float elements in the namespaces (ensures safe type inference).<br><br>
#
#     2. `setup()`: Set baseline parameters (called *second* when initializing).
#     3. `allocate()`: Create grids and allocate solution and simulation memory (called *third* when initializing).
#
# 2. **Type-inference:** When initializing the model the `settings()`, `setup()` and `allocate()` methods are called, and the types of all variables in the namespaces are inferred. Results can be seen by `print(model)`. *Types and number of dimensions in arrays must not change afterwards.*
# 3. The **solve()** method solves the model
# 4. The **simulate()** method simulates the model
# 5. The **save()** method saves the model naming it **savefolder/name**
# 6. The **copy()** makes a deep copy of the model

# %% [markdown]
# In addition to **DurableConsumptionModel.py**, this folder contains the following files:
#
# 1. **last_period.py**: calculate consumption and value function in last period
# 2. **utility.py**: utility function and marginal utility function
# 3. **trans.py**: state transition functions
# 4. **post_decision.py**: calcualte $w$ and $q$
# 5. **nvfi.py**: solve with nested value function iteration
# 6. **negm.py**: solve with the nested endogenous grid method
# 7. **simulate.py**: simulate for all solution methods
# 8. **figs.py**: plot figures
# 9. **tabs.py**: prints tables in .tex files
#
# The functions in these modules are loaded in **DurableConsumptionModel.py**.
#
# The folder **cppfuncs** contains C++ functions not used in this notebook.

# %% [markdown]
# # Setup

# %%
# %load_ext autoreload
# %autoreload 2

#%pip install EconModel
#%pip install ConSav
#%pip install quantecon

import time
import numpy as np

# load the DurableConsumptionModel module
from DurableConsumptionModel import DurableConsumptionModelClass

# %% [markdown]
# ## Choose number of threads in numba

# %%
import numba as nb
nb.set_num_threads(4) #perhaps set to 8

# %% [markdown]
# # Settings

# %% [markdown]
# Choose number of periods to solve:

# %%
T = 5

# %% [markdown]
# # NVFI - nested value function iteration

# %% [markdown]
# Define the **post-decision value function** as
#
# $$ w_{t}(p_{t},n_{t},a_{t}) = \beta \mathbb{E}_{t}[v_{t+1}(m_{t+1},n_{t+1},p_{t+1})] $$
#
# The **keeper problem** can then be written:
#
# $$
# \begin{aligned}
# v_{t}^{keep}(p_{t},n_{t},m_{t})&=\max_{c_{t}}u(c_{t},n_{t})+ w_{t}(p_{t},n_{t},a_{t})]\\&\text{s.t.}&\\a_{t}&=&m_{t}-c_{t}\geq0
# \end{aligned}
# $$
#
# The **adjuster problem** can further be written:
#
# $$
# \begin{aligned}
# v_{t}^{adj.}(x_{t})&=\max_{d_{t}}v_{t}^{keep}(p_{t},d_{t},n_{t})\\&\text{s.t.}&\\m_{t}&=&x_{t}-d_{t}
# \end{aligned}
# $$
#
# **NVFI** solves this reformulated problem.

# %%
model_nvfi = DurableConsumptionModelClass(name='example_negm',par={'solmethod':'nvfi','T':T,'do_print':True})
print(model_nvfi)
# Out:
# Modelclass: DurableConsumptionModelClass
# Name: example_negm
#
# namespaces: ['par', 'sim', 'sol']
# other_attrs: []
# savefolder: saved
# cpp_filename: cppfuncs/main.cpp
#
# par:
#  do_2d = False
#  T = 50 [int]
#  beta = 0.965 [float]
#  rho = 2.0 [float]
#  alpha = 0.9 [float]
#  d_ubar = 0.01 [float]
#  d1_ubar = 0.01 [float]
#  d2_ubar = 0.01 [float]
#  R = 1.03 [float]
#  tau = 0.1 [float]
#  tau1 = 0.08 [float]
#  tau2 = 0.12 [float]
#  delta = 0.15 [float]
#  delta1 = 0.1 [float]
#  delta2 = 0.2 [float]
#  gamma = 0.5 [float]
#  sigma_psi = 0.1 [float]
#  Npsi = 5 [int]
#  sigma_xi = 0.1 [float]
#  Nxi = 5 [int]
#  pi = 0.0 [float]
#  mu = 0.5 [float]
#  Np = 50 [int]
#  p_min = 0.0001 [float]
#  p_max = 3.0 [float]
#  Nn = 50 [int]
#  n_max = 3.0 [float]
#  Nm = 100 [int]
#  m_max = 10.0 [float]
#  Nx = 100 [int]
#  x_max = 13.0 [float]
#  Na = 100 [int]
#  a_max = 11.0 [float]
#  sigma_p0 = 0.2 [float]
#  mu_d0 = 0.8 [float]
#  sigma_d0 = 0.2 [float]
#  mu_a0 = 0.2 [float]
#  sigma_a0 = 0.1 [float]
#  simN = 100000 [int]
#  sim_seed = 1998 [int]
#  euler_cutoff = 0.02 [float]
#  solmethod = nvfi [str]
#  t = 0 [int]
#  tol = 1e-08 [float]
#  do_print = True
#  do_print_period = False
#  cppthreads = 8 [int]
#  do_simple_wq = False
#  do_marg_u = False
#  grid_p = ndarray with shape = (50,) [dtype: float64]
#  grid_n = ndarray with shape = (50,) [dtype: float64]
#  grid_m = ndarray with shape = (100,) [dtype: float64]
#  grid_x = ndarray with shape = (100,) [dtype: float64]
#  grid_a = ndarray with shape = (100,) [dtype: float64]
#  psi = ndarray with shape = (25,) [dtype: float64]
#  psi_w = ndarray with shape = (25,) [dtype: float64]
#  xi = ndarray with shape = (25,) [dtype: float64]
#  xi_w = ndarray with shape = (25,) [dtype: float64]
#  Nshocks = 25 [int]
#  time_w = ndarray with shape = (50,) [dtype: float64]
#  time_keep = ndarray with shape = (50,) [dtype: float64]
#  time_adj = ndarray with shape = (50,) [dtype: float64]
#  time_adj_full = ndarray with shape = (50,) [dtype: float64]
#  time_adj_d1 = ndarray with shape = (50,) [dtype: float64]
#  time_adj_d2 = ndarray with shape = (50,) [dtype: float64]
#  memory, gb: 0.0
#
# sim:
#  p0 = ndarray with shape = (100000,) [dtype: float64]
#  d0 = ndarray with shape = (100000,) [dtype: float64]
#  d10 = ndarray with shape = (0,) [dtype: float64]
#  d20 = ndarray with shape = (0,) [dtype: float64]
#  a0 = ndarray with shape = (100000,) [dtype: float64]
#  utility = ndarray with shape = (100000,) [dtype: float64]
#  p = ndarray with shape = (50, 100000) [dtype: float64]
#  m = ndarray with shape = (50, 100000) [dtype: float64]
#  n = ndarray with shape = (50, 100000) [dtype: float64]
#  n1 = ndarray with shape = (0, 0) [dtype: float64]
#  n2 = ndarray with shape = (0, 0) [dtype: float64]
#  discrete = ndarray with shape = (50, 100000) [dtype: int32]
#  d = ndarray with shape = (50, 100000) [dtype: float64]
#  d1 = ndarray with shape = (0, 0) [dtype: float64]
#  d2 = ndarray with shape = (0, 0) [dtype: float64]
#  c = ndarray with shape = (50, 100000) [dtype: float64]
#  a = ndarray with shape = (50, 100000) [dtype: float64]
#  euler_error = ndarray with shape = (49, 100000) [dtype: float64]
#  euler_error_c = ndarray with shape = (49, 100000) [dtype: float64]
#  euler_error_rel = ndarray with shape = (49, 100000) [dtype: float64]
#  psi = ndarray with shape = (50, 100000) [dtype: float64]
#  xi = ndarray with shape = (50, 100000) [dtype: float64]
#  memory, gb: 0.5
#
# sol:
#  c_keep = ndarray with shape = (50, 50, 50, 100) [dtype: float64]
#  inv_v_keep = ndarray with shape = (50, 50, 50, 100) [dtype: float64]
#  inv_marg_u_keep = ndarray with shape = (50, 50, 50, 100) [dtype: float64]
#  d_adj = ndarray with shape = (50, 50, 100) [dtype: float64]
#  c_adj = ndarray with shape = (50, 50, 100) [dtype: float64]
#  inv_v_adj = ndarray with shape = (50, 50, 100) [dtype: float64]
#  inv_marg_u_adj = ndarray with shape = (50, 50, 100) [dtype: float64]
#  inv_w = ndarray with shape = (49, 50, 50, 100) [dtype: float64]
#  q = ndarray with shape = (49, 50, 50, 100) [dtype: float64]
#  q_c = ndarray with shape = (49, 50, 50, 100) [dtype: float64]
#  q_m = ndarray with shape = (49, 50, 50, 100) [dtype: float64]
#  c_keep_2d = ndarray with shape = (0, 0, 0, 0, 0) [dtype: float64]
#  inv_v_keep_2d = ndarray with shape = (0, 0, 0, 0, 0) [dtype: float64]
#  inv_marg_u_keep_2d = ndarray with shape = (0, 0, 0, 0, 0) [dtype: float64]
#  d1_adj_full_2d = ndarray with shape = (0, 0, 0) [dtype: float64]
#  d2_adj_full_2d = ndarray with shape = (0, 0, 0) [dtype: float64]
#  c_adj_full_2d = ndarray with shape = (0, 0, 0) [dtype: float64]
#  inv_v_adj_full_2d = ndarray with shape = (0, 0, 0) [dtype: float64]
#  inv_marg_u_adj_full_2d = ndarray with shape = (0, 0, 0) [dtype: float64]
#  d1_adj_d1_2d = ndarray with shape = (0, 0, 0, 0) [dtype: float64]
#  c_adj_d1_2d = ndarray with shape = (0, 0, 0, 0) [dtype: float64]
#  inv_v_adj_d1_2d = ndarray with shape = (0, 0, 0, 0) [dtype: float64]
#  inv_marg_u_adj_d1_2d = ndarray with shape = (0, 0, 0, 0) [dtype: float64]
#  d2_adj_d2_2d = ndarray with shape = (0, 0, 0, 0) [dtype: float64]
#  c_adj_d2_2d = ndarray with shape = (0, 0, 0, 0) [dtype: float64]
#  inv_v_adj_d2_2d = ndarray with shape = (0, 0, 0, 0) [dtype: float64]
#  inv_marg_u_adj_d2_2d = ndarray with shape = (0, 0, 0, 0) [dtype: float64]
#  inv_w_2d = ndarray with shape = (0, 0, 0, 0, 0) [dtype: float64]
#  q_2d = ndarray with shape = (0, 0, 0, 0, 0) [dtype: float64]
#  q_c_2d = ndarray with shape = (0, 0, 0, 0, 0) [dtype: float64]
#  q_m_2d = ndarray with shape = (0, 0, 0, 0, 0) [dtype: float64]
#  memory, gb: 0.7

# %%
model_nvfi.precompile_numba() # solve with very coarse grids
model_nvfi.solve()
model_nvfi.simulate()
model_nvfi.save()
# Out:
# numba precompiled in 28.6 secs
#  t = 49 solved in 0.0 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.5 secs
#   solved adjuster problem in 0.0 secs
#  t = 48 solved in 0.6 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.5 secs
#   solved adjuster problem in 0.0 secs
#  t = 47 solved in 1.2 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.5 secs
#   solved adjuster problem in 0.0 secs
#  t = 46 solved in 1.7 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.5 secs
#   solved adjuster problem in 0.0 secs
#  t = 45 solved in 2.3 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.5 secs
#   solved adjuster problem in 0.0 secs
#  t = 44 solved in 2.9 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.5 secs
#   solved adjuster problem in 0.0 secs
#  t = 43 solved in 3.5 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 42 solved in 3.9 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 41 solved in 4.4 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 40 solved in 4.9 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 39 solved in 5.4 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 38 solved in 5.9 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 37 solved in 6.4 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 36 solved in 6.9 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 35 solved in 7.4 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 34 solved in 7.9 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 33 solved in 8.3 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 32 solved in 8.8 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 31 solved in 9.3 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 30 solved in 9.8 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 29 solved in 10.3 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 28 solved in 10.8 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 27 solved in 11.2 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 26 solved in 11.7 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 25 solved in 12.2 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 24 solved in 12.6 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 23 solved in 13.1 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 22 solved in 13.5 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 21 solved in 14.0 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 20 solved in 14.5 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 19 solved in 14.9 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 18 solved in 15.4 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 17 solved in 15.9 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 16 solved in 16.4 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 15 solved in 16.9 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 14 solved in 17.4 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 13 solved in 17.9 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.5 secs
#   solved adjuster problem in 0.0 secs
#  t = 12 solved in 18.4 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 11 solved in 18.9 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 10 solved in 19.4 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 9 solved in 19.9 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 8 solved in 20.4 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 7 solved in 20.8 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 6 solved in 21.3 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 5 solved in 21.8 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 4 solved in 22.3 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 3 solved in 22.7 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 2 solved in 23.2 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 1 solved in 23.7 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 0 solved in 24.1 secs
# model simulated in 1.2 secs
# euler errors calculated in 0.0 secs
# utility calculated in 0.0 secs

# %%
model_nvfi.solve()
model_nvfi.simulate()
model_nvfi.save()
# Out:
#  t = 49 solved in 0.0 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.5 secs
#   solved adjuster problem in 0.0 secs
#  t = 48 solved in 0.6 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 47 solved in 1.0 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 46 solved in 1.5 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 45 solved in 2.0 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.5 secs
#   solved adjuster problem in 0.0 secs
#  t = 44 solved in 2.6 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.5 secs
#   solved adjuster problem in 0.0 secs
#  t = 43 solved in 3.2 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.5 secs
#   solved adjuster problem in 0.0 secs
#  t = 42 solved in 3.8 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 41 solved in 4.3 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.5 secs
#   solved adjuster problem in 0.0 secs
#  t = 40 solved in 4.9 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 39 solved in 5.5 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 38 solved in 5.9 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 37 solved in 6.5 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 36 solved in 7.0 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 35 solved in 7.5 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 34 solved in 8.0 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 33 solved in 8.5 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 32 solved in 9.0 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 31 solved in 9.5 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.5 secs
#   solved adjuster problem in 0.0 secs
#  t = 30 solved in 10.0 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 29 solved in 10.6 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 28 solved in 11.0 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 27 solved in 11.5 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 26 solved in 12.0 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 25 solved in 12.4 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 24 solved in 12.9 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 23 solved in 13.4 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 22 solved in 13.9 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 21 solved in 14.3 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 20 solved in 14.8 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 19 solved in 15.3 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 18 solved in 15.8 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.5 secs
#   solved adjuster problem in 0.0 secs
#  t = 17 solved in 16.4 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 16 solved in 16.9 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 15 solved in 17.4 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.5 secs
#   solved adjuster problem in 0.0 secs
#  t = 14 solved in 18.0 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.5 secs
#   solved adjuster problem in 0.0 secs
#  t = 13 solved in 18.6 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 12 solved in 19.1 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 11 solved in 19.7 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 10 solved in 20.2 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.5 secs
#   solved adjuster problem in 0.0 secs
#  t = 9 solved in 20.7 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 8 solved in 21.2 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 7 solved in 21.7 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 6 solved in 22.2 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 5 solved in 22.7 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 4 solved in 23.2 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 3 solved in 23.6 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.5 secs
#   solved adjuster problem in 0.0 secs
#  t = 2 solved in 24.2 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 1 solved in 24.7 secs
#   w computed in 0.1 secs
#   solved keeper problem in 0.4 secs
#   solved adjuster problem in 0.0 secs
#  t = 0 solved in 25.2 secs
# model simulated in 1.2 secs
# euler errors calculated in 0.0 secs
# utility calculated in 0.0 secs

# %% [markdown]
# **Plot** interactive decision functions:

# %%
model_nvfi.decision_functions()

# %% [markdown]
# **Plot** life-cycle profiles:

# %%
model_nvfi.lifecycle()

# %% [markdown]
# # NEGM - nested endogenous grid method

# %% [markdown]
# Define the **post-decision marginal value of cash:**
#
# $$
# \begin{aligned}
# q_{t}(p_{t},d_{t},a_{t})&=\beta R\mathbb{E}_{t}[u_{c}(c_{t+1},d_{t+1})]\\
# &=&\beta R\mathbb{E}_{t}[\alpha c_{t+1}^{\alpha(1-\rho)-1}d_{t+1}^{(1-\alpha)(1-\rho)}]
# \end{aligned}
# $$
#
# Note that all optimal interior consumption choices must satisfy the **Euler-equation**
#
# $$
# \begin{aligned}
# u_{c}(c_{t},d_{t})=\alpha c_{t}^{\alpha(1-\rho)-1}d_{t}^{(1-\alpha)(1-\rho)}&=q(p_{t},d_{t},a_{t})
# \end{aligned}
# $$
#
# This implies that we have an analytical mapping from the post-decision space $(p_t,d_t,a_t)$ to consumption and cash-on-hand $(c_t,m_t)$:
#
# $$
# \begin{aligned}
# c_{t} &=\frac{1}{\alpha}\left(\frac{q(a_{t},d_{t},p_{t})}{d_{t}^{(1-\alpha)(1-\rho)}}\right)^{\alpha(1-\rho)-1}
# \\
# m_{t} &= a_{t}+c_{t}
# \end{aligned}
# $$
#
# **NEGM** uses this mapping (and an upperenvelope algorithm) to solve the keeper problem much faster.

# %%
model_negm = DurableConsumptionModelClass(name='example_negm',par={'solmethod':'negm','T':T,'do_print':True})
model_negm.precompile_numba() # solve with very coarse grids
model_negm.solve()
model_negm.simulate()
model_negm.save()

# %% [markdown]
# **Plot** interactive decision functions:

# %%
model_negm.decision_functions()

# %% [markdown]
# **Plot** life-cycle profiles:

# %%
model_negm.lifecycle()

# %% [markdown]
# # Compare life-cycles from NVFI and NEGM

# %%
from figs import lifecycle_compare
lifecycle_compare(model_negm,'negm',model_nvfi,'nvfi')

# %% [markdown]
# # Compare life-cycle profiles with VFI

# %%
model_vfi = DurableConsumptionModelClass(name='example_vfi',par={'solmethod':'vfi','T':T,'do_print':True})
model_vfi.precompile_numba() # solve with very coarse grids
model_vfi.solve()
model_vfi.simulate()
model_vfi.save()

# %%
lifecycle_compare(model_negm,'negm',model_vfi,'vfi')
